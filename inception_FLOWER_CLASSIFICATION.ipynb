# %%
import numpy as np
import pandas as pd

import os
print(os.listdir("/content/drive/MyDrive/Colab Notebooks/my_projects/flower_recog"))
# Out:
# ['cnn_flower_recognition.ipynb', 'RESNET_50_FLOWER_CLASSIFICATION.ipynb', 'Untitled0.ipynb', 'new_label', 'Untitled1.ipynb', 'mobilenet_finetuning.ipynb', 'VGG_FLOWER.ipynb', 'data', 'cnn_model.h5']

# %%
# !pip3 install resnet
# Out:
# Requirement already satisfied: resnet in /usr/local/lib/python3.7/dist-packages (0.1)
# Requirement already satisfied: keras>=2.0 in /usr/local/lib/python3.7/dist-packages (from resnet) (2.4.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras>=2.0->resnet) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras>=2.0->resnet) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras>=2.0->resnet) (3.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras>=2.0->resnet) (3.13)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py->keras>=2.0->resnet) (1.5.2)

# %%
from tensorflow.python.keras.applications.resnet import ResNet50
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, BatchNormalization
from tensorflow.python.keras.applications.resnet import preprocess_input
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.preprocessing.image import load_img, img_to_array

# %%
data_generator = ImageDataGenerator(horizontal_flip=True,
                                   width_shift_range = 0.4,
                                   height_shift_range = 0.4,
                                   zoom_range=0.3,
                                   rotation_range=20,
                                   )

image_size = 299
batch_size = 10
train_generator = data_generator.flow_from_directory(
        '/content/drive/MyDrive/Colab Notebooks/my_projects/flower_recog/data/',
        target_size=(image_size, image_size),
        batch_size=batch_size,
        class_mode='categorical')

num_classes = len(train_generator.class_indices)
# Out:
# Found 480 images belonging to 6 classes.

# %%
from keras.applications import inception_v3
from keras.applications.inception_v3 import InceptionV3
model = Sequential()

model.add(InceptionV3(weights = 'imagenet', include_top = False, input_shape=(299, 299, 3)))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(2048, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(num_classes, activation='softmax'))

model.layers[0].trainable = False

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
count = sum([len(files) for r, d, files in os.walk("../input/flowers-recognition/flowers/flowers/")])

model.fit_generator(
        train_generator,
        steps_per_epoch=int(count/batch_size) + 1,
        epochs=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 1/1 [==============================] - 14s 14s/step - loss: 2.6162 - accuracy: 0.2000
# Epoch 2/100
# 1/1 [==============================] - 7s 7s/step - loss: 2.4441 - accuracy: 0.3000
# Epoch 3/100
# 1/1 [==============================] - 7s 7s/step - loss: 3.2289 - accuracy: 0.4000
# Epoch 4/100
# 1/1 [==============================] - 7s 7s/step - loss: 4.7244 - accuracy: 0.4000
# Epoch 5/100
# 1/1 [==============================] - 7s 7s/step - loss: 5.4955 - accuracy: 0.3000
# Epoch 6/100
# 1/1 [==============================] - 6s 6s/step - loss: 5.1949 - accuracy: 0.3000
# Epoch 7/100
# 1/1 [==============================] - 7s 7s/step - loss: 1.5395 - accuracy: 0.5000
# Epoch 8/100
# 1/1 [==============================] - 6s 6s/step - loss: 2.9409 - accuracy: 0.6000
# Epoch 9/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.4883 - accuracy: 0.5000
# Epoch 10/100
# 1/1 [==============================] - 6s 6s/step - loss: 2.4637 - accuracy: 0.6000
# Epoch 11/100
# 1/1 [==============================] - 6s 6s/step - loss: 2.3018 - accuracy: 0.6000
# Epoch 12/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.6721 - accuracy: 0.5000
# Epoch 13/100
# 1/1 [==============================] - 6s 6s/step - loss: 2.4443 - accuracy: 0.4000
# Epoch 14/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.6924 - accuracy: 0.5000
# Epoch 15/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.9527 - accuracy: 0.5000
# Epoch 16/100
# 1/1 [==============================] - 6s 6s/step - loss: 3.1117 - accuracy: 0.3000
# Epoch 17/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.0479 - accuracy: 0.7000
# Epoch 18/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.8108 - accuracy: 0.6000
# Epoch 19/100
# 1/1 [==============================] - 6s 6s/step - loss: 3.3690 - accuracy: 0.2000
# Epoch 20/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.6604 - accuracy: 0.6000
# Epoch 21/100
# 1/1 [==============================] - 7s 7s/step - loss: 1.6907 - accuracy: 0.5000
# Epoch 22/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.1961 - accuracy: 0.4000
# Epoch 23/100
# 1/1 [==============================] - 6s 6s/step - loss: 2.4134 - accuracy: 0.2000
# Epoch 24/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.6635 - accuracy: 0.6000
# Epoch 25/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.8439 - accuracy: 0.3000
# Epoch 26/100
# 1/1 [==============================] - 6s 6s/step - loss: 2.9007 - accuracy: 0.3000
# Epoch 27/100
# 1/1 [==============================] - 5s 5s/step - loss: 2.1073 - accuracy: 0.3000
# Epoch 28/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.4924 - accuracy: 0.5000
# Epoch 29/100
# 1/1 [==============================] - 7s 7s/step - loss: 1.8175 - accuracy: 0.5000
# Epoch 30/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.8444 - accuracy: 0.7000
# Epoch 31/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.2241 - accuracy: 0.6000
# Epoch 32/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.0861 - accuracy: 0.5000
# Epoch 33/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.3486 - accuracy: 0.5000
# Epoch 34/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.2661 - accuracy: 0.5000
# Epoch 35/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.0834 - accuracy: 0.5000
# Epoch 36/100
# 1/1 [==============================] - 6s 6s/step - loss: 2.0870 - accuracy: 0.5000
# Epoch 37/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.5347 - accuracy: 0.3000
# Epoch 38/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.2418 - accuracy: 0.5000
# Epoch 39/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.7741 - accuracy: 0.2000
# Epoch 40/100
# 1/1 [==============================] - 5s 5s/step - loss: 2.2769 - accuracy: 0.4000
# Epoch 41/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.8979 - accuracy: 0.4000
# Epoch 42/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.8001 - accuracy: 0.3000
# Epoch 43/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.0124 - accuracy: 0.6000
# Epoch 44/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.8764 - accuracy: 0.7000
# Epoch 45/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.0476 - accuracy: 0.6000
# Epoch 46/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.1697 - accuracy: 0.7000
# Epoch 47/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.4616 - accuracy: 0.7000
# Epoch 48/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.0212 - accuracy: 0.5000
# Epoch 49/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.9739 - accuracy: 0.6000
# Epoch 50/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.5271 - accuracy: 0.5000
# Epoch 51/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.0809 - accuracy: 0.6000
# Epoch 52/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.4155 - accuracy: 0.4000
# Epoch 53/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.9128 - accuracy: 0.6000
# Epoch 54/100
# 1/1 [==============================] - 6s 6s/step - loss: 2.1133 - accuracy: 0.4000
# Epoch 55/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.4422 - accuracy: 0.5000
# Epoch 56/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.1993 - accuracy: 0.6000
# Epoch 57/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.4337 - accuracy: 0.5000
# Epoch 58/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.3448 - accuracy: 0.7000
# Epoch 59/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1462 - accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.7141 - accuracy: 0.7000
# Epoch 61/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.8324 - accuracy: 0.6000
# Epoch 62/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2973 - accuracy: 0.9000
# Epoch 63/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.5299 - accuracy: 0.7000
# Epoch 64/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.1106 - accuracy: 0.5000
# Epoch 65/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.0783 - accuracy: 0.4000
# Epoch 66/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.8760 - accuracy: 0.7000
# Epoch 67/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.0271 - accuracy: 0.6000
# Epoch 68/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.5952 - accuracy: 0.8000
# Epoch 69/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.7372 - accuracy: 0.8000
# Epoch 70/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.2231 - accuracy: 0.6000
# Epoch 71/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.4957 - accuracy: 0.7000
# Epoch 72/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.9409 - accuracy: 0.5000
# Epoch 73/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.5529 - accuracy: 0.3000
# Epoch 74/100
# 1/1 [==============================] - 5s 5s/step - loss: 2.0394 - accuracy: 0.4000
# Epoch 75/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.5403 - accuracy: 0.6000
# Epoch 76/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.3652 - accuracy: 0.9000
# Epoch 77/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.4790 - accuracy: 0.8000
# Epoch 78/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.9782 - accuracy: 0.8000
# Epoch 79/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.7902 - accuracy: 0.5000
# Epoch 80/100
# 1/1 [==============================] - 6s 6s/step - loss: 2.2568 - accuracy: 0.3000
# Epoch 81/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.2867 - accuracy: 0.7000
# Epoch 82/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.6106 - accuracy: 0.9000
# Epoch 83/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.0954 - accuracy: 0.8000
# Epoch 84/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.3032 - accuracy: 0.9000
# Epoch 85/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.7053 - accuracy: 0.8000
# Epoch 86/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.1262 - accuracy: 0.5000
# Epoch 87/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.8716 - accuracy: 0.6000
# Epoch 88/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.7922 - accuracy: 0.7000
# Epoch 89/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.5215 - accuracy: 0.8000
# Epoch 90/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.5252 - accuracy: 0.9000
# Epoch 91/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.8077 - accuracy: 0.6000
# Epoch 92/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.5663 - accuracy: 0.8000
# Epoch 93/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.3611 - accuracy: 0.3000
# Epoch 94/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.5219 - accuracy: 0.5000
# Epoch 95/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.5541 - accuracy: 0.8000
# Epoch 96/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.9699 - accuracy: 0.8000
# Epoch 97/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.7556 - accuracy: 0.6000
# Epoch 98/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.8746 - accuracy: 0.7000
# Epoch 99/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.6450 - accuracy: 0.8000
# Epoch 100/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.1322 - accuracy: 0.6000

# %%
from IPython.display import Image, display

import os, random
img_locations = []
for d in os.listdir("/content/drive/MyDrive/Colab Notebooks/my_projects/flower_recog/data/"):
    directory = "/content/drive/MyDrive/Colab Notebooks/my_projects/flower_recog/data/" + d
    sample = [directory + '/' + s for s in random.sample(
        os.listdir(directory), int(random.random()*10))]
    img_locations += sample

# %%
def read_and_prep_images(img_paths, img_height=image_size, img_width=image_size):
    imgs = [load_img(img_path, target_size=(img_height, img_width)) for img_path in img_paths]
    img_array = np.array([img_to_array(img) for img in imgs])
    return preprocess_input(img_array)

random.shuffle(img_locations)
imgs = read_and_prep_images(img_locations)
predictions = model.predict_classes(imgs)
classes = dict((v,k) for k,v in train_generator.class_indices.items())

for img, prediction in zip(img_locations, predictions):
    display(Image(img))
    print(classes[prediction])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# scilia
# scilia
# scilia
# Sunflower
# scilia
# toad_lilly
# toad_lilly
# Sunflower
# scilia
# orris_root
# toad_lilly
# Sunflower
# scilia
# orris_root
# flowering_dogwood
# toad_lilly
# scilia
# Sunflower
# flowering_dogwood
# scilia
# scilia
# toad_lilly
# Sunflower
# Sunflower
# flowering_dogwood
# flowering_dogwood
# toad_lilly
# scilia
# Sunflower
# flowering_dogwood
# scilia
